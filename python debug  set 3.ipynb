# %%
#1.What is wrong with the following function definition, and how do you fix it?


def say_hello(name)
    print("Hello, " + name)

# %%
# Ans: colon is missing
def say_hello(name): 
    print("Hello, " + name)

# %%
#2.What error will occur in the following code, and how do you fix it?


age = 25
print("I am " + age + " years old")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       1 #2.What error will occur in the following code, and how do you fix it?
#       4 age = 25
# ----> 5 print("I am " + age + " years old")
#
# TypeError: can only concatenate str (not "int") to str

# %%
#Ans: 

age = 25
print("I am " + str(age) + " years old")
# Out:
# I am 25 years old

# %%
#3.Question:
What is the issue with the following code?

def greet():
    message = "Hello"
print(message)
# Out:
# Object `code` not found.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 6
#       4 def greet():
#       5     message = "Hello"
# ----> 6 print(message)
#
# NameError: name 'message' is not defined

# %%
#Ans: print statement front space issue

def greet():
    message = "Hello"
    print(message)

# %%
greet()
# Out:
# Hello

# %%
#4.What error will occur in the following code, and how do you fix it?

def add(a, b):
    return a + b

print(add(5))
# Out:
# 11

# %%
#Ans: one argument is missing

# %%
def add(a, b):
    return a + b

print(add(5,6))
# Out:
# 11

# %%
#5.What is wrong with this code?

def is_even(n):
    if n % 2 == 1:
        return True
    else:
        return False

# %%
#ANS: no value are passing , so i have used call function with value, if we want print statement , we can use inside of the if condition
is_even(5)
# Out:
# True

# %%
#6.What happens when you run this code?

num = int("10a")
print(num)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 3
#       1 #6.What happens when you run this code?
# ----> 3 num = int("10a")
#       4 print(num)
#
# ValueError: invalid literal for int() with base 10: '10a'

# %%
#ANS: int is only indicate the numbers
num = int("10")
print(num)

#or
# Out:
# 10

# %%
num ="10a"
print(str(num))
# Out:
# 10a

# %%
#7.What will happen when you run the following code?


numbers = [1, 2, 3, 4]
numbers.sort().reverse()
print(numbers)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 5
#       1 #7.What will happen when you run the following code?
#       4 numbers = [1, 2, 3, 4]
# ----> 5 numbers.sort().reverse()
#       6 print(numbers)
#
# AttributeError: 'NoneType' object has no attribute 'reverse'

# %%
#ANS: we can use by different steps , first sort the order then we can reverse it, after we can print it
numbers = [1, 2, 3, 4]
numbers.sort()
numbers.reverse()
print(numbers)
# Out:
# [4, 3, 2, 1]

# %%
#8.What is the issue with this code?


numbers = [1, 2, 3]
numbers = numbers.append(4)
print(numbers)
# Out:
# None

# %%
#ANS: sry unable to find it , i will try later
numbers = [1, 2, 3]
y=numbers
print(y.append(4))
# Out:
# None

# %%
#9.What will happen when you run the following code?


count = 10

def increment():
    count += 1
    print(count)

increment()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[31], line 10
#       7     count += 1
#       8     print(count)
# ---> 10 increment()
#
# Cell In[31], line 7, in increment()
#       6 def increment():
# ----> 7     count += 1
#       8     print(count)
#
# UnboundLocalError: cannot access local variable 'count' where it is not associated with a value

# %%
#ANS: Exactly not sure, but i can understand like function will take the variable value via incide of the function of passing arguments

def increment():
    count = 10
    count += 1
    print(count)

increment()
# Out:
# 11

# %%
#10.What error will occur in the following code?

text = "Python"
print(text[10])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[34], line 4
#       1 #10.What error will occur in the following code?
#       3 text = "Python"
# ----> 4 print(text[10])
#
# IndexError: string index out of range

# %%
#ANS:as per above given value 'Python' is have 5 array only , so 10 is exceed of the array
text = "Python"
print(text[5])
# Out:
# n
